# %%
import pandas as pd

# %%
# path to the excel file
file_path = 'dataset/Case Study for Data Scientist.xlsx'

# read the second sheet
df = pd.read_excel(file_path, sheet_name = 1, skiprows = 1)
df
# Out:
#        Day       Date Region Mill Code Mill Type  Actual OER %  \
# 0      Wed 2020-01-01    R01      Z001        IP          0.00
# 1      Thu 2020-01-02    R01      Z001        IP         22.27
# 2      Fri 2020-01-03    R01      Z001        IP         22.55
# 3      Sat 2020-01-04    R01      Z001        IP         22.12
# 4      Sun 2020-01-05    R01      Z001        IP          0.00
# ...    ...        ...    ...       ...       ...           ...
# 56507  Sun 2024-10-27    R03      Z031        MB          0.00
# 56508  Mon 2024-10-28    R03      Z031        MB         20.06
# 56509  Tue 2024-10-29    R03      Z031        MB         20.55
# 56510  Wed 2024-10-30    R03      Z031        MB         21.72
# 56511  Thu 2024-10-31    R03      Z031        MB          0.00
#
#        Crop Freshness Score     Ripe %  Long Stalk %  Rat Damage %  ...  \
# 0                300.000000  95.157670      1.241942      4.734563  ...
# 1                289.458286  95.430159      1.859710      3.931418  ...
# 2                262.890977  94.617481      1.514098      3.568296  ...
# 3                262.653835  95.404031      1.457055      4.809152  ...
# 4                       NaN        NaN           NaN           NaN  ...
# ...                     ...        ...           ...           ...  ...
# 56507            288.465184  93.306517      0.000000      7.516356  ...
# 56508            279.591628  91.514008      1.048533      7.877966  ...
# 56509            283.408589  90.271842      2.299574      9.977223  ...
# 56510            279.003379  93.746667      1.530594      7.984932  ...
# 56511                   NaN        NaN           NaN           NaN  ...
#
#        Rainfall (mm)  Age Profile (years)  Total Oil Losses %  Downtime %  \
# 0           0.000000            15.721261            0.000000    0.000000
# 1           3.342912            13.950932            1.387521    0.254744
# 2          24.355107            13.322048            1.484348    0.058243
# 3           1.208765            14.120394            1.364690    0.099324
# 4                NaN                  NaN            0.000000    0.000000
# ...              ...                  ...                 ...         ...
# 56507       0.396669            16.703111            0.000000    0.000000
# 56508       0.000000            16.002074            1.418109    0.055674
# 56509       0.000000            16.075206            1.696618    0.173986
# 56510       0.211507            16.364601            1.668725    0.046099
# 56511            NaN                  NaN            0.000000    0.000000
#
#        FFB Processed (MT)   Seed A %  Seed B %  Other Seeds %  Coastal %  \
# 0                   0.000  31.114312       0.0      68.885688  49.290868
# 1                 648.373  39.927122       0.0      60.072878  46.188086
# 2                 530.021  37.392953       0.0      62.607047  45.361864
# 3                 702.527  33.681927       0.0      66.318073  51.698756
# 4                   0.000        NaN       NaN            NaN        NaN
# ...                   ...        ...       ...            ...        ...
# 56507               0.000  70.281260       0.0      29.718740   0.000000
# 56508             821.564  56.788672       0.0      43.211328   0.000000
# 56509             792.973  44.036217       0.0      55.963783   0.000000
# 56510             896.667  50.160957       0.0      49.839043   0.000000
# 56511               0.000        NaN       NaN            NaN        NaN
#
#          Inland %
# 0       50.709132
# 1       53.811914
# 2       54.638136
# 3       48.301244
# 4             NaN
# ...           ...
# 56507  100.000000
# 56508  100.000000
# 56509  100.000000
# 56510  100.000000
# 56511         NaN
#
# [56512 rows x 21 columns]
